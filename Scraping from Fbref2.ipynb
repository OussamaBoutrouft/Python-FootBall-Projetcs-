# %%
import pandas as pd
import numpy as np

from scipy import stats
import math

from mplsoccer import PyPizza, add_image, FontManager
import matplotlib.pyplot as plt

# %%
df=pd.read_html('https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats', 
                attrs ={"id":"results2022-202391_overall"})[0]

# %%
df.head(20)
# Out:
#     Rk            Squad  MP   W   D   L  GF  GA  GD  Pts  Pts/MP    xG   xGA  \
# 0    1  Manchester City  38  28   5   5  94  33  61   89    2.34  78.6  32.1
# 1    2          Arsenal  38  26   6   6  88  43  45   84    2.21  71.7  42.0
# 2    3   Manchester Utd  38  23   6   9  58  43  15   75    1.97  67.7  50.4
# 3    4    Newcastle Utd  38  19  14   5  68  33  35   71    1.87  71.9  39.5
# 4    5        Liverpool  38  19  10   9  75  47  28   67    1.76  71.5  50.8
# 5    6         Brighton  38  18   8  12  72  53  19   62    1.63  73.3  50.2
# 6    7      Aston Villa  38  18   7  13  51  46   5   61    1.61  50.3  52.5
# 7    8        Tottenham  38  18   6  14  70  63   7   60    1.58  57.0  49.6
# 8    9        Brentford  38  15  14   9  58  46  12   59    1.55  56.3  48.8
# 9   10           Fulham  38  15   7  16  55  53   2   52    1.37  46.2  63.6
# 10  11   Crystal Palace  38  11  12  15  40  49  -9   45    1.18  39.3  48.1
# ...

# %%
df=pd.read_html('https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats', attrs ={"id":"stats_standard_9"})[0]

# %%
df.head(20)
# Out:
#         Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Player             Nation                Pos
# 0                  Alisson             br BRA                 GK
# 1            Mohamed Salah             eg EGY                 FW
# 2   Trent Alexander-Arnold            eng ENG                 DF
# 3          Virgil van Dijk             nl NED                 DF
# 4                  Fabinho             br BRA                 MF
# 5         Andrew Robertson            sct SCO                 DF
# 6         Jordan Henderson            eng ENG                 MF
# 7             Darwin Núñez             uy URU                 FW
# 8           Harvey Elliott            eng ENG              MF,FW
# 9          Ibrahima Konaté             fr FRA                 DF
# 10              Cody Gakpo             nl NED              FW,MF
# 11               Joe Gomez            eng ENG                 DF
# ...
