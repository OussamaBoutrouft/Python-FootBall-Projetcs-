# %%
import pandas as pd
from mplsoccer import Pitch

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
parser= Sbopen()

# %%
df, related, freeze, tactics = parser.event(3895250)

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'out', 'off_camera', 'pass_switch',
#        'counterpress', 'shot_statsbomb_xg', 'end_z', 'shot_first_time',
#        'technique_id', 'technique_name', 'goalkeeper_position_id',
#        'goalkeeper_position_name', 'pass_cross', 'pass_deflected',
#        'ball_recovery_recovery_failure', 'block_offensive', 'aerial_won',
# ...

# %%
df[df['team_name']=='Bayer Leverkusen']
# Out:
#                                         id  index  period        timestamp  \
# 0     63d94113-a4e0-45a3-b4de-87b8d27d5524      1       1         00:00:00
# 3     213df70e-f903-4676-b38b-4d61ba9902f7      4       1         00:00:00
# 4     2c8959ba-eede-48db-a7c3-c06853b94042      5       1  00:00:01.186000
# 5     9ae6b567-1335-4c07-a8c3-4846ac6bfb8c      6       1  00:00:02.406000
# 6     3a631406-a22f-4a5c-af49-72a60bcef71d      7       1  00:00:02.406000
# ...                                    ...    ...     ...              ...
# 3817  d9f5b634-a78e-45e6-9bd4-baf0da0ca96b   3818       2  00:49:04.395000
# 3818  0b401ef2-a5c8-4f19-b24c-a2e98d106cc4   3819       2  00:49:04.457000
# 3821  3af97e24-6b83-41f1-96ac-2a5a92fda801   3822       2  00:49:06.297000
# 3823  65c995a1-1ac7-4aeb-aefc-4d776ebf9338   3824       2  00:49:07.513000
# 3824  73c645f7-e26d-40ac-8128-4111eea7e02f   3825       2  00:49:10.942000
#
# ...

# %%
df['outcome_name'].unique()
# Out:
# array([nan, 'Incomplete', 'Out', 'Success In Play', 'Goal', 'No Touch',
#        'Claim', 'Pass Offside', 'Won', 'Saved', 'Success', 'Lost Out',
#        'Lost', 'Success To Team', 'Complete', 'Unknown', 'Blocked',
#        'Saved Twice', 'Touched Out', 'In Play Danger', 'Wayward', 'Off T',
#        'Lost In Play', 'Punched out', 'Saved Off Target', 'Tactical',
#        'Clear', 'Touched In'], dtype=object)

# %%
df['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt', 'Carry',
#        'Pressure', 'Block', 'Miscontrol', 'Interception', 'Ball Recovery',
#        'Foul Committed', 'Foul Won', 'Shot', 'Goal Keeper', 'Clearance',
#        'Dispossessed', 'Duel', '50/50', 'Dribbled Past', 'Dribble',
#        'Injury Stoppage', 'Referee Ball-Drop', 'Error', 'Shield',
#        'Bad Behaviour', 'Half End', 'Tactical Shift', 'Substitution'],
#       dtype=object)

# %%
df['player_id'].unique()
# Out:
# array([    nan,   8804.,  27133.,  30606.,  11278.,  10336.,   8221.,
#         32712.,   5623.,  13315.,   8403.,   3500.,  23402.,   8207.,
#          7796.,  40724., 363583.,   9195.,  10480.,  19405.,   8667.,
#         33401.,  15458.,   7044.,   8230.,  40707.,  41411.,  38917.,
#         38004.,  28239.])

# %%
passes = df[df['type_name']=='Pass']
filtered = passes[['player_name','x','y','end_x', 'end_y','pass_recipient_name','outcome_id','outcome_name']]

# %%
filtered[filtered['outcome_name'].isnull()]
# Out:
#                     player_name     x     y  end_x  end_y  \
# 4                 Jonas Hofmann  61.0  40.1   39.7   48.5
# 7               Odilon Kossonou  41.3  47.5   46.3   16.3
# 11        Edmond Fayçal Tapsoba  48.0  17.0   57.0    5.0
# 14    Alejandro Grimaldo García  56.0   5.2   38.5    3.8
# 17        Edmond Fayçal Tapsoba  25.7  22.7   25.9   38.8
# ...                         ...   ...   ...    ...    ...
# 3796               Nadiem Amiri  56.9  24.3   66.9   30.0
# 3799               Jae-Sung Lee  66.9  30.0   63.8   29.4
# 3803   Leandro Barreiro Martins  65.3  28.9   73.8   29.2
# 3806                  Tom Krauß  71.8  29.2   71.3   36.2
# 3810               Jae-Sung Lee  70.1  36.4   85.1   41.3
#
#             pass_recipient_name  outcome_id outcome_name
# 4               Odilon Kossonou         NaN          NaN
# 7         Edmond Fayçal Tapsoba         NaN          NaN
# 11    Alejandro Grimaldo García         NaN          NaN
# ...

# %%
dfLeverkusen= df[(df['player_name']=='Jonas Hofmann')]

# %%
customcmap = matplotlib.colors.LinearSegmentedColormap.from_list('customcmap',['black','red'])

# %%
pitch = mplsoccer.VerticalPitch(pitch_type='opta',pitch_color='black',line_color='white')
fig,ax = pitch.draw(figsize= (8, 16))
fig.set_facecolor('black')

pitch.kdeplot(dfLeverkusen['x'],dfLeverkusen['y'],ax=ax,cmap =customcmap , shade=True, n_levels=100 , zorder = 0)
fig.suptitle(y = 0.85 ,t='where does passes of jonas hofmann end  ?' , color = 'white', fontsize = '20')
# Out:
# C:\Users\oussama\anaconda3\Lib\site-packages\mplsoccer\_pitch_plot.py:170: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   return sns.kdeplot(x=x, y=y, ax=ax, clip=self.kde_clip, **kwargs)
# C:\Users\oussama\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\oussama\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 0.85, 'where does passes of jonas hofmann end  ?')
