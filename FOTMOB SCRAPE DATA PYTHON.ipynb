# %%
import requests


params = {
    'matchId': '4193910',
}

response = requests.get('https://www.fotmob.com/api/matchDetails', params=params)

# %%
data = response.json()

# %%
shotmap = data['content']['shotmap']['shots']

# %%
shotmap[0]
# Out:
# {'id': 2689624121,
#  'eventType': 'Miss',
#  'teamId': 8657,
#  'playerId': 820581,
#  'playerName': 'Ben Brereton Diaz',
#  'x': 92.9,
#  'y': 24.139363062099996,
#  'min': 3,
#  'minAdded': None,
#  'isBlocked': False,
#  'isOnTarget': False,
#  'blockedX': None,
#  'blockedY': None,
#  'goalCrossedY': 31.026249999999997,
#  'goalCrossedZ': 4.4630344888,
#  'expectedGoals': 0.03706395998597145,
#  'expectedGoalsOnTarget': None,
#  'shotType': 'RightFoot',
#  'situation': 'RegularPlay',
#  'period': 'FirstHalf',
#  'isOwnGoal': False,
#  'onGoalShot': {'x': 1.4512553642644517,
#   'y': 0.6772486772486772,
#   'zoomRatio': 0.5736007656728462},
#  'isSavedOffLine': False,
#  'isFromInsideBox': True,
#  'firstName': 'Ben Brereton',
#  'lastName': 'Diaz',
#  'fullName': 'Ben Brereton Diaz',
#  'shortName': 'Brereton Diaz',
#  'teamColor': '#E30613'}

# %%
import pandas as pd
df = pd.DataFrame(shotmap)

# %%
df.head(20)
# Out:
#             id     eventType  teamId  playerId         playerName           x  \
# 0   2689624121          Miss    8657    820581  Ben Brereton Diaz   92.900000
# 1   2689630891  AttemptSaved    8657    775355      Gustavo Hamer   83.160680
# 2   2689635673          Post    8657    820581  Ben Brereton Diaz   98.921053
# 3   2689641783          Goal    8586    935379   Dejan Kulusevski   95.543860
# 4   2689651803  AttemptSaved    8586    935379   Dejan Kulusevski   95.640351
# 5   2689655519  AttemptSaved    8586    935379   Dejan Kulusevski   85.279412
# 6   2689655729  AttemptSaved    8586    493165     James Maddison   97.473684
# 7   2689660119          Post    8586    620618  Rodrigo Bentancur   87.211765
# 8   2689660173  AttemptSaved    8586    212867      Heung-Min Son   92.200000
# 9   2689660457          Miss    8586    789066    Cristian Romero   97.666667
# 10  2689663401  AttemptSaved    8586    941573        Pedro Porro   84.399515
# 11  2689664119  AttemptSaved    8657   1086647     Cameron Archer   91.000000
# 12  2689666519  AttemptSaved    8657    775355      Gustavo Hamer   84.512136
# 13  2689676105  AttemptSaved    8586    493165     James Maddison   96.508772
# 14  2689676351  AttemptSaved    8586   1076756    Brennan Johnson   99.114035
# 15  2689700465          Goal    8586    941573        Pedro Porro   92.100000
# 16  2689704925  AttemptSaved    8586    212867      Heung-Min Son  100.258621
# 17  2689705989          Goal    8586    935379   Dejan Kulusevski   96.219298
# 18  2689718771  AttemptSaved    8586    789066    Cristian Romero   96.122807
# 19  2689718981          Miss    8657    841150     Rhian Brewster   88.177941
#
#             y  min  minAdded  isBlocked  ...      period  isOwnGoal  \
# 0   24.139363    3       NaN      False  ...   FirstHalf      False
# 1   43.720510    7       NaN      False  ...   FirstHalf      False
# 2   30.244000   10       NaN      False  ...   FirstHalf      False
# 3   45.752357   14       NaN      False  ...   FirstHalf      False
# 4   25.533750   21       NaN      False  ...   FirstHalf      False
# 5   31.636250   24       NaN       True  ...   FirstHalf      False
# 6   30.568750   24       NaN       True  ...   FirstHalf      False
# 7   35.067500   29       NaN      False  ...   FirstHalf      False
# 8   36.363750   29       NaN      False  ...   FirstHalf      False
# 9   34.991250   29       NaN      False  ...   FirstHalf      False
# 10  22.177580   33       NaN      False  ...   FirstHalf      False
# 11  38.788571   33       NaN       True  ...   FirstHalf      False
# 12  42.177188   36       NaN       True  ...   FirstHalf      False
# 13  37.507500   45       1.0      False  ...   FirstHalf      False
# 14  21.967389   45       1.0       True  ...   FirstHalf      False
# 15  26.169688   59       NaN      False  ...  SecondHalf      False
# 16  46.663185   64       NaN      False  ...  SecondHalf      False
# 17  37.744000   65       NaN      False  ...  SecondHalf      False
# 18  32.475000   79       NaN      False  ...  SecondHalf      False
# 19  22.107516   80       NaN      False  ...  SecondHalf      False
#
#                                            onGoalShot  isSavedOffLine  \
# 0   {'x': 1.4512553642644517, 'y': 0.6772486772486...           False
# 1   {'x': 1.6051587301587305, 'y': 0.3329434681481...           False
# 2   {'x': 1.9841269841269837, 'y': 0.2802840420634...           False
# 3   {'x': 1.7867063492063497, 'y': 0.0424672791005...           False
# 4   {'x': 0.7579365079365064, 'y': 0.0220829851322...           False
# 5   {'x': 1.141203703703705, 'y': 0.32275132116402...           False
# 6   {'x': 0.2536375661375645, 'y': 0.3227513211640...           False
# 7   {'x': 1.9809523809523806, 'y': 0.0866332493650...           False
# 8   {'x': 0.455357142857142, 'y': 0.31255917417989...           False
# 9   {'x': 2, 'y': 0.022544044500805074, 'zoomRatio...           False
# 10  {'x': 0.21329365079365015, 'y': 0.064550264232...           False
# 11  {'x': 1.665674603174603, 'y': 0.32275132116402...           False
# 12  {'x': 0.9394841269841275, 'y': 0.3227513211640...           False
# 13  {'x': 1.121031746031747, 'y': 0.06455026423280...           False
# 14  {'x': 0.41501322751322767, 'y': 0.322751321164...           False
# 15  {'x': 1.1815476190476193, 'y': 0.3873015853968...           False
# 16  {'x': 0.31415343915343885, 'y': 0.010192146984...           False
# 17  {'x': 1.4639550264550256, 'y': 0.0424672791005...           False
# 18  {'x': 1, 'y': 0.5486772459788359, 'zoomRatio': 1}           False
# 19  {'x': -2.220446049250313e-16, 'y': 0.020534900...           False
#
#     isFromInsideBox     firstName    lastName           fullName  \
# 0              True  Ben Brereton        Diaz  Ben Brereton Diaz
# 1             False       Gustavo       Hamer      Gustavo Hamer
# 2              True  Ben Brereton        Diaz  Ben Brereton Diaz
# 3              True         Dejan  Kulusevski   Dejan Kulusevski
# 4              True         Dejan  Kulusevski   Dejan Kulusevski
# 5             False         Dejan  Kulusevski   Dejan Kulusevski
# 6              True         James    Maddison     James Maddison
# 7             False       Rodrigo   Bentancur  Rodrigo Bentancur
# 8              True     Heung-Min         Son      Heung-Min Son
# 9              True      Cristian      Romero    Cristian Romero
# 10            False         Pedro       Porro        Pedro Porro
# 11             True       Cameron      Archer     Cameron Archer
# 12            False       Gustavo       Hamer      Gustavo Hamer
# 13             True         James    Maddison     James Maddison
# 14             True       Brennan     Johnson    Brennan Johnson
# 15             True         Pedro       Porro        Pedro Porro
# 16             True     Heung-Min         Son      Heung-Min Son
# 17             True         Dejan  Kulusevski   Dejan Kulusevski
# 18             True      Cristian      Romero    Cristian Romero
# 19            False         Rhian    Brewster     Rhian Brewster
#
#         shortName teamColor
# 0   Brereton Diaz   #E30613
# 1             NaN   #E30613
# 2   Brereton Diaz   #E30613
# 3             NaN   #132257
# 4             NaN   #132257
# 5             NaN   #132257
# 6             NaN   #132257
# 7             NaN   #132257
# 8             NaN   #132257
# 9             NaN   #132257
# 10            NaN   #132257
# 11            NaN   #E30613
# 12            NaN   #E30613
# 13            NaN   #132257
# 14            NaN   #132257
# 15            NaN   #132257
# 16            NaN   #132257
# 17            NaN   #132257
# 18            NaN   #132257
# 19            NaN   #E30613
#
# [20 rows x 29 columns]

# %%
df.to_csv('/Users/Oussama/Documents/fotmob.csv')
