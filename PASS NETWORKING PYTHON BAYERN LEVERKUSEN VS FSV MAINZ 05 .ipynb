# %%
import pandas as pd
from mplsoccer import Pitch,Sbopen

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
parser= Sbopen()

# %%
df, related, freeze, tactics = parser.event(3895250)

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'under_pressure',
#        'outcome_id', 'outcome_name', 'out', 'off_camera', 'pass_switch',
#        'counterpress', 'shot_statsbomb_xg', 'end_z', 'shot_first_time',
#        'technique_id', 'technique_name', 'goalkeeper_position_id',
#        'goalkeeper_position_name', 'pass_cross', 'pass_deflected',
#        'ball_recovery_recovery_failure', 'block_offensive', 'aerial_won',
#        'pass_cut_back', 'pass_assisted_shot_id', 'pass_goal_assist',
#        'shot_key_pass_id', 'pass_shot_assist', 'foul_won_defensive',
#        'pass_miscommunication', 'foul_committed_card_id',
#        'foul_committed_card_name', 'bad_behaviour_card_id',
#        'bad_behaviour_card_name', 'block_save_block',
#        'substitution_replacement_id', 'substitution_replacement_name',
#        'dribble_overrun'],
#       dtype='object')

# %%
df = df[df['team_name']=='Bayer Leverkusen']

# %%
df['outcome_name'].unique()
# Out:
# array([nan, 'Incomplete', 'Goal', 'Claim', 'No Touch', 'Success',
#        'Success To Team', 'Won', 'Complete', 'Saved Twice', 'Saved',
#        'Wayward', 'Lost', 'Success In Play', 'Pass Offside', 'Blocked',
#        'Out', 'Lost In Play', 'Off T', 'Saved Off Target', 'Unknown',
#        'Lost Out', 'Tactical'], dtype=object)

# %%
df['type_name'].unique()
# Out:
# array(['Starting XI', 'Half Start', 'Pass', 'Ball Receipt', 'Carry',
#        'Miscontrol', 'Pressure', 'Block', 'Ball Recovery', 'Foul Won',
#        'Shot', 'Goal Keeper', 'Clearance', 'Dispossessed',
#        'Foul Committed', 'Duel', '50/50', 'Interception', 'Dribble',
#        'Dribbled Past', 'Injury Stoppage', 'Referee Ball-Drop', 'Shield',
#        'Bad Behaviour', 'Half End', 'Tactical Shift', 'Error',
#        'Substitution'], dtype=object)

# %%
df['player_id'].unique()
# Out:
# array([   nan,  8804., 27133., 30606., 10336.,  8221., 32712.,  3500.,
#        40724.,  9195.,  8667., 33401.,  7044., 41411., 38004., 28239.])

# %%
passes = df[df['type_name']=='Pass']
filtered = passes[['player_name','x','y','end_x', 'end_y','pass_recipient_name','outcome_id','outcome_name']]

# %%
filtered[filtered['outcome_name'].isnull()]
# Out:
#                       player_name     x     y  end_x  end_y  \
# 4                   Jonas Hofmann  61.0  40.1   39.7   48.5
# 7                 Odilon Kossonou  41.3  47.5   46.3   16.3
# 11          Edmond Fayçal Tapsoba  48.0  17.0   57.0    5.0
# 14      Alejandro Grimaldo García  56.0   5.2   38.5    3.8
# 17          Edmond Fayçal Tapsoba  25.7  22.7   25.9   38.8
# ...                           ...   ...   ...    ...    ...
# 3741                 Granit Xhaka  80.2   7.7   84.4    0.9
# 3744  Piero Martín Hincapié Reyna  77.7   1.2   56.1    1.8
# 3747        Edmond Fayçal Tapsoba  56.1   1.8   73.1    1.4
# 3766                 Jonathan Tah  48.3  29.5   62.7   33.4
# 3785               Robert Andrich  58.9  56.7   70.7   58.0
#
#               pass_recipient_name  outcome_id outcome_name
# 4                 Odilon Kossonou         NaN          NaN
# 7           Edmond Fayçal Tapsoba         NaN          NaN
# 11      Alejandro Grimaldo García         NaN          NaN
# 14          Edmond Fayçal Tapsoba         NaN          NaN
# 17                   Jonathan Tah         NaN          NaN
# ...                           ...         ...          ...
# 3741  Piero Martín Hincapié Reyna         NaN          NaN
# 3744        Edmond Fayçal Tapsoba         NaN          NaN
# 3747  Piero Martín Hincapié Reyna         NaN          NaN
# 3766                Patrik Schick         NaN          NaN
# 3785                  Adam Hložek         NaN          NaN
#
# [622 rows x 8 columns]

# %%
df_lineup = parser.lineup(3895250)
jersey_data=df_lineup[['player_id','jersey_number']]

# %%
df= pd.merge(df,jersey_data,on='player_id')

# %%
#player id is the jersey number
df['passer'] = df['jersey_number']
passes = df[df['type_name']=='Pass']
successful = passes[passes['outcome_name'].isnull()]

# %%
rec= pd.to_numeric(successful['pass_recipient_id'],downcast='integer')
jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
jersey_data.rename(columns={'jersey_number':'pass_recipient'},inplace=True)
successful=pd.merge(df,jersey_data,on='pass_recipient_id')
successful
# Out:
# C:\Users\oussama\AppData\Local\Temp\ipykernel_5236\1439914159.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jersey_data.rename(columns={'player_id':'pass_recipient_id'},inplace=True)
# C:\Users\oussama\AppData\Local\Temp\ipykernel_5236\1439914159.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   jersey_data.rename(columns={'jersey_number':'pass_recipient'},inplace=True)
#                                        id  index  period        timestamp  \
# 0    2c8959ba-eede-48db-a7c3-c06853b94042      5       1  00:00:01.186000
# 1    79925e3b-8d47-4f73-aa82-1cb6cf1dd86b   1849       1  00:47:03.140000
# 2    3202c957-e311-45ac-bbfe-2115e3946018   2046       2  00:03:32.651000
# 3    bda4480a-996c-4314-9329-d3c4d38f19fa     66       1  00:01:21.332000
# 4    09b15207-b186-46e7-a0a4-5b4a6fb65f7b    132       1  00:04:50.931000
# ..                                    ...    ...     ...              ...
# 698  34c5c44c-5055-4cc2-b399-19faa68dda47   3376       2  00:40:12.111000
# 699  761a476c-b2db-4ce0-9d69-e569a84ed10b   3231       2  00:37:48.943000
# 700  041952e6-4f4e-41d4-91ea-5a0847b2303e   3531       2  00:42:48.336000
# 701  72b414c0-a776-48fa-bab5-2c0483a431ac   3553       2  00:43:01.605000
# 702  2b7b8ee6-2e6b-4902-96bb-b37baada6848   3615       2  00:44:31.299000
#
#      minute  second  possession  duration  match_id  type_id  ...  \
# 0         0       1           2  1.219663   3895250       30  ...
# 1        47       3          86  1.300945   3895250       30  ...
# 2        48      32          98  1.075243   3895250       30  ...
# 3         1      21           5  2.705411   3895250       30  ...
# 4         4      50          10  1.208637   3895250       30  ...
# ..      ...     ...         ...       ...       ...      ...  ...
# 698      85      12         162  2.047792   3895250       30  ...
# 699      82      48         156  0.981946   3895250       30  ...
# 700      87      48         166  0.791556   3895250       30  ...
# 701      88       1         168  1.394741   3895250       30  ...
# 702      89      31         170  1.505392   3895250       30  ...
#
#     foul_committed_card_name  bad_behaviour_card_id bad_behaviour_card_name  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
# ..                       ...                    ...                     ...
# 698                      NaN                    NaN                     NaN
# 699                      NaN                    NaN                     NaN
# 700                      NaN                    NaN                     NaN
# 701                      NaN                    NaN                     NaN
# 702                      NaN                    NaN                     NaN
#
#      block_save_block substitution_replacement_id  \
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
# ..                ...                         ...
# 698               NaN                         NaN
# 699               NaN                         NaN
# 700               NaN                         NaN
# 701               NaN                         NaN
# 702               NaN                         NaN
#
#      substitution_replacement_name dribble_overrun jersey_number  passer  \
# 0                              NaN             NaN             7       7
# 1                              NaN             NaN             7       7
# 2                              NaN             NaN             7       7
# 3                              NaN             NaN            12      12
# 4                              NaN             NaN            12      12
# ..                             ...             ...           ...     ...
# 698                            NaN             NaN            34      34
# 699                            NaN             NaN            10      10
# 700                            NaN             NaN            14      14
# 701                            NaN             NaN            14      14
# 702                            NaN             NaN            23      23
#
#     pass_recipient
# 0                6
# 1                6
# 2                6
# 3                6
# 4                6
# ..             ...
# 698             19
# 699             19
# 700             19
# 701             19
# 702             19
#
# [703 rows x 73 columns]

# %%
subs = df[df['type_name']=='Substitution']
subs = subs['minute']
firstSub=subs.min()

# %%
firstSub
# Out:
# 55

# %%
successful = successful[successful['minute']<firstSub]

# %%
successful
# Out:
#                                        id  index  period        timestamp  \
# 0    2c8959ba-eede-48db-a7c3-c06853b94042      5       1  00:00:01.186000
# 1    79925e3b-8d47-4f73-aa82-1cb6cf1dd86b   1849       1  00:47:03.140000
# 2    3202c957-e311-45ac-bbfe-2115e3946018   2046       2  00:03:32.651000
# 3    bda4480a-996c-4314-9329-d3c4d38f19fa     66       1  00:01:21.332000
# 4    09b15207-b186-46e7-a0a4-5b4a6fb65f7b    132       1  00:04:50.931000
# ..                                    ...    ...     ...              ...
# 654  1c049abd-8bbf-41f9-b835-f3d4b05a67c5    953       1  00:22:42.670000
# 657  131196b1-f3ef-4013-98ea-7fe7a377a74a    908       1  00:21:18.631000
# 659  20ed8552-1113-4e45-86c0-dbe6868987c0    325       1  00:09:49.165000
# 660  7f27c0d1-f150-4fad-a977-57678a1f8a0c    386       1  00:11:15.296000
# 661  127057f3-f5d3-406d-af85-4c939af3c140    743       1  00:17:58.370000
#
#      minute  second  possession  duration  match_id  type_id  ...  \
# 0         0       1           2  1.219663   3895250       30  ...
# 1        47       3          86  1.300945   3895250       30  ...
# 2        48      32          98  1.075243   3895250       30  ...
# 3         1      21           5  2.705411   3895250       30  ...
# 4         4      50          10  1.208637   3895250       30  ...
# ..      ...     ...         ...       ...       ...      ...  ...
# 654      22      42          39  0.965561   3895250       30  ...
# 657      21      18          37  3.803408   3895250       30  ...
# 659       9      49          22  1.266405   3895250       30  ...
# 660      11      15          23  3.120306   3895250       30  ...
# 661      17      58          35  1.917262   3895250       30  ...
#
#     foul_committed_card_name  bad_behaviour_card_id bad_behaviour_card_name  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
# ..                       ...                    ...                     ...
# 654                      NaN                    NaN                     NaN
# 657                      NaN                    NaN                     NaN
# 659                      NaN                    NaN                     NaN
# 660                      NaN                    NaN                     NaN
# 661                      NaN                    NaN                     NaN
#
#      block_save_block substitution_replacement_id  \
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
# ..                ...                         ...
# 654               NaN                         NaN
# 657               NaN                         NaN
# 659               NaN                         NaN
# 660               NaN                         NaN
# 661               NaN                         NaN
#
#      substitution_replacement_name dribble_overrun jersey_number  passer  \
# 0                              NaN             NaN             7       7
# 1                              NaN             NaN             7       7
# 2                              NaN             NaN             7       7
# 3                              NaN             NaN            12      12
# 4                              NaN             NaN            12      12
# ..                             ...             ...           ...     ...
# 654                            NaN             NaN            12      12
# 657                            NaN             NaN            34      34
# 659                            NaN             NaN             8       8
# 660                            NaN             NaN             8       8
# 661                            NaN             NaN             8       8
#
#     pass_recipient
# 0                6
# 1                6
# 2                6
# 3                6
# 4                6
# ..             ...
# 654              1
# 657              1
# 659              1
# 660              1
# 661              1
#
# [421 rows x 73 columns]

# %%
successful.dtypes
# Out:
# id                               object
# index                             int64
# period                            int64
# timestamp                        object
# minute                            int64
#                                   ...
# substitution_replacement_name    object
# dribble_overrun                  object
# jersey_number                     int64
# passer                            int64
# pass_recipient                    int64
# Length: 73, dtype: object

# %%
successful
# Out:
#                                        id  index  period        timestamp  \
# 0    2c8959ba-eede-48db-a7c3-c06853b94042      5       1  00:00:01.186000
# 1    79925e3b-8d47-4f73-aa82-1cb6cf1dd86b   1849       1  00:47:03.140000
# 2    3202c957-e311-45ac-bbfe-2115e3946018   2046       2  00:03:32.651000
# 3    bda4480a-996c-4314-9329-d3c4d38f19fa     66       1  00:01:21.332000
# 4    09b15207-b186-46e7-a0a4-5b4a6fb65f7b    132       1  00:04:50.931000
# ..                                    ...    ...     ...              ...
# 654  1c049abd-8bbf-41f9-b835-f3d4b05a67c5    953       1  00:22:42.670000
# 657  131196b1-f3ef-4013-98ea-7fe7a377a74a    908       1  00:21:18.631000
# 659  20ed8552-1113-4e45-86c0-dbe6868987c0    325       1  00:09:49.165000
# 660  7f27c0d1-f150-4fad-a977-57678a1f8a0c    386       1  00:11:15.296000
# 661  127057f3-f5d3-406d-af85-4c939af3c140    743       1  00:17:58.370000
#
#      minute  second  possession  duration  match_id  type_id  ...  \
# 0         0       1           2  1.219663   3895250       30  ...
# 1        47       3          86  1.300945   3895250       30  ...
# 2        48      32          98  1.075243   3895250       30  ...
# 3         1      21           5  2.705411   3895250       30  ...
# 4         4      50          10  1.208637   3895250       30  ...
# ..      ...     ...         ...       ...       ...      ...  ...
# 654      22      42          39  0.965561   3895250       30  ...
# 657      21      18          37  3.803408   3895250       30  ...
# 659       9      49          22  1.266405   3895250       30  ...
# 660      11      15          23  3.120306   3895250       30  ...
# 661      17      58          35  1.917262   3895250       30  ...
#
#     foul_committed_card_name  bad_behaviour_card_id bad_behaviour_card_name  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3                        NaN                    NaN                     NaN
# 4                        NaN                    NaN                     NaN
# ..                       ...                    ...                     ...
# 654                      NaN                    NaN                     NaN
# 657                      NaN                    NaN                     NaN
# 659                      NaN                    NaN                     NaN
# 660                      NaN                    NaN                     NaN
# 661                      NaN                    NaN                     NaN
#
#      block_save_block substitution_replacement_id  \
# 0                 NaN                         NaN
# 1                 NaN                         NaN
# 2                 NaN                         NaN
# 3                 NaN                         NaN
# 4                 NaN                         NaN
# ..                ...                         ...
# 654               NaN                         NaN
# 657               NaN                         NaN
# 659               NaN                         NaN
# 660               NaN                         NaN
# 661               NaN                         NaN
#
#      substitution_replacement_name dribble_overrun jersey_number  passer  \
# 0                              NaN             NaN             7       7
# 1                              NaN             NaN             7       7
# 2                              NaN             NaN             7       7
# 3                              NaN             NaN            12      12
# 4                              NaN             NaN            12      12
# ..                             ...             ...           ...     ...
# 654                            NaN             NaN            12      12
# 657                            NaN             NaN            34      34
# 659                            NaN             NaN             8       8
# 660                            NaN             NaN             8       8
# 661                            NaN             NaN             8       8
#
#     pass_recipient
# 0                6
# 1                6
# 2                6
# 3                6
# 4                6
# ..             ...
# 654              1
# 657              1
# 659              1
# 660              1
# 661              1
#
# [421 rows x 73 columns]

# %%
df['pass_recipient_id'].unique()
# Out:
# array([27133.,    nan, 32712.,  3500., 33401.,  8221., 40724., 10336.,
#         9195., 30606.,  8804.,  8667.,  7044., 38004., 28239., 41411.])

# %%
average_locations= successful.groupby('passer').agg({'x':['mean'],'y':['mean','count']})
average_locations.columns = ['x','y','count']

# %%
average_locations
# Out:
#                 x          y  count
# passer
# 1        9.276923  41.876923     13
# 4       54.373684  43.771053     38
# 6       50.507143  65.785714     42
# 7       80.969697  51.357576     33
# 8       61.087037  38.574074     54
# 10      80.048837  29.546512     43
# 12      51.960000  21.956364     55
# 20      74.615385  13.876923     39
# 21      65.487500  37.687500     16
# 30      73.496667  65.436667     30
# 34      61.625862  39.325862     58

# %%
pass_between = successful.groupby(['passer','pass_recipient']).id.count().reset_index()
pass_between.rename({'id':'pass_count'},axis='columns',inplace=True)
pass_between
# Out:
#     passer  pass_recipient  pass_count
# 0        1               4           1
# 1        1               6           2
# 2        1               7           3
# 3        1              12           1
# 4        1              21           3
# ..     ...             ...         ...
# 86      34              10          10
# 87      34              12           8
# 88      34              20          10
# 89      34              21           4
# 90      34              30           6
#
# [91 rows x 3 columns]

# %%
pass_between= pass_between.merge(average_locations,left_on='passer',right_index=True)
pass_between
# Out:
#     passer  pass_recipient  pass_count          x          y  count
# 0        1               4           1   9.276923  41.876923     13
# 1        1               6           2   9.276923  41.876923     13
# 2        1               7           3   9.276923  41.876923     13
# 3        1              12           1   9.276923  41.876923     13
# 4        1              21           3   9.276923  41.876923     13
# ..     ...             ...         ...        ...        ...    ...
# 86      34              10          10  61.625862  39.325862     58
# 87      34              12           8  61.625862  39.325862     58
# 88      34              20          10  61.625862  39.325862     58
# 89      34              21           4  61.625862  39.325862     58
# 90      34              30           6  61.625862  39.325862     58
#
# [91 rows x 6 columns]

# %%
pass_between= pass_between.merge(average_locations,left_on='pass_recipient',right_index=True,suffixes=['','_end'])
pass_between
# Out:
#     passer  pass_recipient  pass_count          x          y  count  \
# 0        1               4           1   9.276923  41.876923     13
# 15       6               4           7  50.507143  65.785714     42
# 24       7               4           3  80.969697  51.357576     33
# 34       8               4           5  61.087037  38.574074     54
# 43      10               4           3  80.048837  29.546512     43
# ..     ...             ...         ...        ...        ...    ...
# 90      34              30           6  61.625862  39.325862     58
# 14       6               1           1  50.507143  65.785714     42
# 33       8               1           3  61.087037  38.574074     54
# 52      12               1           1  51.960000  21.956364     55
# 81      34               1           1  61.625862  39.325862     58
#
#         x_end      y_end  count_end
# 0   54.373684  43.771053         38
# 15  54.373684  43.771053         38
# 24  54.373684  43.771053         38
# 34  54.373684  43.771053         38
# 43  54.373684  43.771053         38
# ..        ...        ...        ...
# 90  73.496667  65.436667         30
# 14   9.276923  41.876923         13
# 33   9.276923  41.876923         13
# 52   9.276923  41.876923         13
# 81   9.276923  41.876923         13
#
# [91 rows x 9 columns]

# %%
pass_between =pass_between[pass_between['pass_count']>3]
pass_between.drop_duplicates()
pass_between
# Out:
#     passer  pass_recipient  pass_count          x          y  count  \
# 15       6               4           7  50.507143  65.785714     42
# 34       8               4           5  61.087037  38.574074     54
# 53      12               4           5  51.960000  21.956364     55
# 82      34               4           6  61.625862  39.325862     58
# 6        4               6           6  54.373684  43.771053     38
# 35       8               6           6  61.087037  38.574074     54
# 75      30               6           8  73.496667  65.436667     30
# 83      34               6           5  61.625862  39.325862     58
# 16       6               7           7  50.507143  65.785714     42
# 63      20               7           4  74.615385  13.876923     39
# 76      30               7           7  73.496667  65.436667     30
# 10       4              12          11  54.373684  43.771053     38
# 38       8              12          12  61.087037  38.574074     54
# 66      20              12          10  74.615385  13.876923     39
# 87      34              12           8  61.625862  39.325862     58
# 30       7              21           5  80.969697  51.357576     33
# 49      10              21           8  80.048837  29.546512     43
# 59      12              21           5  51.960000  21.956364     55
# 89      34              21           4  61.625862  39.325862     58
# 13       4              34           8  54.373684  43.771053     38
# 23       6              34           6  50.507143  65.785714     42
# 42       8              34          10  61.087037  38.574074     54
# 61      12              34          12  51.960000  21.956364     55
# 73      21              34           5  65.487500  37.687500     16
# 80      30              34           6  73.496667  65.436667     30
# 8        4               8           6  54.373684  43.771053     38
# 17       6               8           5  50.507143  65.785714     42
# 26       7               8           4  80.969697  51.357576     33
# 46      10               8           5  80.048837  29.546512     43
# 56      12               8          10  51.960000  21.956364     55
# 64      20               8           7  74.615385  13.876923     39
# 77      30               8           4  73.496667  65.436667     30
# 85      34               8           7  61.625862  39.325862     58
# 27       7              10           7  80.969697  51.357576     33
# 37       8              10           4  61.087037  38.574074     54
# 57      12              10           9  51.960000  21.956364     55
# 65      20              10          12  74.615385  13.876923     39
# 72      21              10           6  65.487500  37.687500     16
# 86      34              10          10  61.625862  39.325862     58
# 48      10              20          11  80.048837  29.546512     43
# 58      12              20           8  51.960000  21.956364     55
# 88      34              20          10  61.625862  39.325862     58
# 22       6              30          10  50.507143  65.785714     42
# 41       8              30           6  61.087037  38.574074     54
# 50      10              30           9  80.048837  29.546512     43
# 90      34              30           6  61.625862  39.325862     58
#
#         x_end      y_end  count_end
# 15  54.373684  43.771053         38
# 34  54.373684  43.771053         38
# 53  54.373684  43.771053         38
# 82  54.373684  43.771053         38
# 6   50.507143  65.785714         42
# 35  50.507143  65.785714         42
# 75  50.507143  65.785714         42
# 83  50.507143  65.785714         42
# 16  80.969697  51.357576         33
# 63  80.969697  51.357576         33
# 76  80.969697  51.357576         33
# 10  51.960000  21.956364         55
# 38  51.960000  21.956364         55
# 66  51.960000  21.956364         55
# 87  51.960000  21.956364         55
# 30  65.487500  37.687500         16
# 49  65.487500  37.687500         16
# 59  65.487500  37.687500         16
# 89  65.487500  37.687500         16
# 13  61.625862  39.325862         58
# 23  61.625862  39.325862         58
# 42  61.625862  39.325862         58
# 61  61.625862  39.325862         58
# 73  61.625862  39.325862         58
# 80  61.625862  39.325862         58
# 8   61.087037  38.574074         54
# 17  61.087037  38.574074         54
# 26  61.087037  38.574074         54
# 46  61.087037  38.574074         54
# 56  61.087037  38.574074         54
# 64  61.087037  38.574074         54
# 77  61.087037  38.574074         54
# 85  61.087037  38.574074         54
# 27  80.048837  29.546512         43
# 37  80.048837  29.546512         43
# 57  80.048837  29.546512         43
# 65  80.048837  29.546512         43
# 72  80.048837  29.546512         43
# 86  80.048837  29.546512         43
# 48  74.615385  13.876923         39
# 58  74.615385  13.876923         39
# 88  74.615385  13.876923         39
# 22  73.496667  65.436667         30
# 41  73.496667  65.436667         30
# 50  73.496667  65.436667         30
# 90  73.496667  65.436667         30

# %%
average_locations['count'].values
pass_between['pass_count'].values
# Out:
# array([ 7,  5,  5,  6,  6,  6,  8,  5,  7,  4,  7, 11, 12, 10,  8,  5,  8,
#         5,  4,  8,  6, 10, 12,  5,  6,  6,  5,  4,  5, 10,  7,  4,  7,  7,
#         4,  9, 12,  6, 10, 11,  8, 10, 10,  6,  9,  6], dtype=int64)

# %%
pass_between
# Out:
#     passer  pass_recipient  pass_count          x          y  count  \
# 15       6               4           7  50.507143  65.785714     42
# 34       8               4           5  61.087037  38.574074     54
# 53      12               4           5  51.960000  21.956364     55
# 82      34               4           6  61.625862  39.325862     58
# 6        4               6           6  54.373684  43.771053     38
# 35       8               6           6  61.087037  38.574074     54
# 75      30               6           8  73.496667  65.436667     30
# 83      34               6           5  61.625862  39.325862     58
# 16       6               7           7  50.507143  65.785714     42
# 63      20               7           4  74.615385  13.876923     39
# 76      30               7           7  73.496667  65.436667     30
# 10       4              12          11  54.373684  43.771053     38
# 38       8              12          12  61.087037  38.574074     54
# 66      20              12          10  74.615385  13.876923     39
# 87      34              12           8  61.625862  39.325862     58
# 30       7              21           5  80.969697  51.357576     33
# 49      10              21           8  80.048837  29.546512     43
# 59      12              21           5  51.960000  21.956364     55
# 89      34              21           4  61.625862  39.325862     58
# 13       4              34           8  54.373684  43.771053     38
# 23       6              34           6  50.507143  65.785714     42
# 42       8              34          10  61.087037  38.574074     54
# 61      12              34          12  51.960000  21.956364     55
# 73      21              34           5  65.487500  37.687500     16
# 80      30              34           6  73.496667  65.436667     30
# 8        4               8           6  54.373684  43.771053     38
# 17       6               8           5  50.507143  65.785714     42
# 26       7               8           4  80.969697  51.357576     33
# 46      10               8           5  80.048837  29.546512     43
# 56      12               8          10  51.960000  21.956364     55
# 64      20               8           7  74.615385  13.876923     39
# 77      30               8           4  73.496667  65.436667     30
# 85      34               8           7  61.625862  39.325862     58
# 27       7              10           7  80.969697  51.357576     33
# 37       8              10           4  61.087037  38.574074     54
# 57      12              10           9  51.960000  21.956364     55
# 65      20              10          12  74.615385  13.876923     39
# 72      21              10           6  65.487500  37.687500     16
# 86      34              10          10  61.625862  39.325862     58
# 48      10              20          11  80.048837  29.546512     43
# 58      12              20           8  51.960000  21.956364     55
# 88      34              20          10  61.625862  39.325862     58
# 22       6              30          10  50.507143  65.785714     42
# 41       8              30           6  61.087037  38.574074     54
# 50      10              30           9  80.048837  29.546512     43
# 90      34              30           6  61.625862  39.325862     58
#
#         x_end      y_end  count_end
# 15  54.373684  43.771053         38
# 34  54.373684  43.771053         38
# 53  54.373684  43.771053         38
# 82  54.373684  43.771053         38
# 6   50.507143  65.785714         42
# 35  50.507143  65.785714         42
# 75  50.507143  65.785714         42
# 83  50.507143  65.785714         42
# 16  80.969697  51.357576         33
# 63  80.969697  51.357576         33
# 76  80.969697  51.357576         33
# 10  51.960000  21.956364         55
# 38  51.960000  21.956364         55
# 66  51.960000  21.956364         55
# 87  51.960000  21.956364         55
# 30  65.487500  37.687500         16
# 49  65.487500  37.687500         16
# 59  65.487500  37.687500         16
# 89  65.487500  37.687500         16
# 13  61.625862  39.325862         58
# 23  61.625862  39.325862         58
# 42  61.625862  39.325862         58
# 61  61.625862  39.325862         58
# 73  61.625862  39.325862         58
# 80  61.625862  39.325862         58
# 8   61.087037  38.574074         54
# 17  61.087037  38.574074         54
# 26  61.087037  38.574074         54
# 46  61.087037  38.574074         54
# 56  61.087037  38.574074         54
# 64  61.087037  38.574074         54
# 77  61.087037  38.574074         54
# 85  61.087037  38.574074         54
# 27  80.048837  29.546512         43
# 37  80.048837  29.546512         43
# 57  80.048837  29.546512         43
# 65  80.048837  29.546512         43
# 72  80.048837  29.546512         43
# 86  80.048837  29.546512         43
# 48  74.615385  13.876923         39
# 58  74.615385  13.876923         39
# 88  74.615385  13.876923         39
# 22  73.496667  65.436667         30
# 41  73.496667  65.436667         30
# 50  73.496667  65.436667         30
# 90  73.496667  65.436667         30

# %%
pitch = Pitch(pitch_color='#FFFFFF', line_color='#B6BBC4')
# Set the figure size
fig, ax = pitch.draw(figsize=(8, 6), constrained_layout=True, tight_layout=False)

# Set the face color of the figure
fig.set_facecolor('#FFFFFF')

# Draw arrows and nodes
# arrows = pitch.arrows(1.2 * pass_between.x, 0.8 * pass_between.y, 1.2 * pass_between.x_end, 0.8 * pass_between.y_end, ax=ax,color='red', alpha=0.4,width=3)
pass_lines = pitch.lines(1.2*pass_between.x, 0.8*pass_between.y, 1.2*pass_between.x_end, 0.8*pass_between.y_end, lw=pass_between.pass_count*0.5,color='red', zorder=1, ax=ax)
                 
nodes = pitch.scatter(1.2 * average_locations.x, 0.8 * average_locations.y, s=20*average_locations['count'].values, color='white', edgecolors='#a6aab3', linewidth=2, alpha=1, zorder=1, ax=ax)

                 
# Annotate average_locations
for index, row in average_locations.iterrows():
    pitch.annotate(index, xy=(1.2 * row.x, 0.8 * row.y), c='#161A30',fontweight='bold', va='center', ha='center', size=8, ax=ax)

# Add the endnote
ax.text(114, 85, '@Oussama-BOUTROUFT', color='#0E2954', va='bottom', ha='center', fontsize=10)

# Add the title
ax.set_title('Bayer LeverkuseN 2-1 FSV Mainz 05', color='red', va='center', ha='center', fontsize=12,fontweight='bold',pad=20,loc='center')
ax.annotate('Bundesliga 2023/24', xy=(0.5, 1), xytext=(0, 0),
             xycoords='axes fraction', textcoords='offset points',
             fontsize=10, color='#0E2954', va='top', ha='center')


plt.show()
